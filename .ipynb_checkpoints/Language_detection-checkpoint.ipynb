# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
import urllib.request
import warnings
warnings.filterwarnings('ignore')

# %%
# data_path = 'https://https://raw.githubusercontent.com/Slimcent/Machine_Learning_Datasets/main/ML/languages.csv'

# def download_read_data(path):
    
#     """
#      Function to retrieve data from the data paths
#      And to read the data as a pandas dataframe
  
#     To return the dataframe
#     """ 
    
#       ## Only retrieve the directory of the data

#     data_path =  urllib.request.urlretrieve(path)[0]
#     data = pd.read_csv(path)
    
#     return data

# %%
# data = download_read_data(data_path)
# data.head()

# %%
# Load the data from CSV
data = pd.read_csv('languages.csv')

# %%
data.head()
# Out:
#                                                 Text  language
# 0  klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1  sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2  ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3  விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4  de spons behoort tot het geslacht haliclona en...     Dutch

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Text      22000 non-null  object
#  1   language  22000 non-null  object
# dtypes: object(2)
# memory usage: 343.9+ KB

# %%
data.describe()
# Out:
#                                                      Text  language
# count                                               22000     22000
# unique                                              21859        22
# top     haec commentatio automatice praeparata res ast...  Estonian
# freq                                                   48      1000

# %%
data.isnull().sum()
# Out:
# Text        0
# language    0
# dtype: int64

# %%
num_languages = data['language'].nunique()

print(f'Number of languages in the dataset is: {num_languages}')
# Out:
# Number of languages in the dataset is: 22

# %%
data["language"].value_counts()
# Out:
# language
# Estonian      1000
# Swedish       1000
# English       1000
# Russian       1000
# Romanian      1000
# Persian       1000
# Pushto        1000
# Spanish       1000
# Hindi         1000
# Korean        1000
# Chinese       1000
# French        1000
# Portugese     1000
# Indonesian    1000
# Urdu          1000
# Latin         1000
# Turkish       1000
# Japanese      1000
# Dutch         1000
# Tamil         1000
# Thai          1000
# Arabic        1000
# Name: count, dtype: int64

# %%
# Check for class imbalance

import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the 'language' column is treated as a categorical variable, rather than string
data['language'] = data['language'].astype('category')

# Plot the distribution of languages
plt.figure(figsize=(10, 4))
sns.countplot(data=data, x='language', order=data['language'].value_counts().index)
plt.title('Distribution of Languages')
plt.xticks(rotation=90)
plt.show()

# %%
# Analyze the length of the text samples to understand their distribution
# This checks the length of each word in the language irrespective of the language name

data['text_length'] = data['Text'].apply(len)
plt.figure(figsize=(10, 4))
sns.histplot(data['text_length'], bins=50, kde=True)
plt.title('Distribution of Text Lengths')
plt.show()

# %%
# Plot the distribution of text lengths for each language

plt.figure(figsize=(10, 4))
sns.histplot(data=data, x='text_length', hue='language', element='step', stat='density', common_norm=False, bins=50)
plt.title('Distribution of Text Lengths by Language')
plt.xlabel('Text Length')
plt.ylabel('Density')
plt.show()

# %%
# Count the Words in each Text

data['word_count'] = data['Text'].apply(lambda x: len(x.split()))

# %%
# Plot of the Distribution of Word Counts by Language

plt.figure(figsize=(10, 4))
sns.histplot(data=data, x='word_count', hue='language', element='step', stat='density', common_norm=False, bins=50)
plt.title('Distribution of Word Counts by Language')
plt.xlabel('Word Count')
plt.ylabel('Density')
plt.show()

# %%
# Calculate the number of words for each language
word_counts = data.groupby('language')['word_count'].sum().reset_index()

# Plot the distribution of word counts for each language
plt.figure(figsize=(14, 6))
sns.barplot(data=word_counts, x='language', y='word_count', order=data['language'].value_counts().index)
plt.title('Distribution of Word Counts by Language')
plt.xlabel('Language')
plt.ylabel('Word Count')
plt.xticks(rotation=90)

# Display the count of words on top of each bar
for index, row in word_counts.iterrows():
    plt.text(index, row['word_count'], f"{row['word_count']:,}", color='black', ha="center")

plt.show()

# %%
# Top Words by Language
# Identify the most frequent words in each language

from sklearn.feature_extraction.text import CountVectorizer

# Limit vocabulary size and use sparse matrices
vectorizer = CountVectorizer(stop_words='english', max_features=5000)
X = vectorizer.fit_transform(data['Text'])

# No need to convert to dense array, keep it sparse
word_counts = pd.DataFrame.sparse.from_spmatrix(X, columns=vectorizer.get_feature_names_out())

# Add language column
word_counts['language'] = data['language']

# Group by language and sum counts
top_words = word_counts.groupby('language').sum().T

# Print top words for each language
for lang in top_words.columns:
    print(f'Top words in {lang}:')
    print(top_words[lang].sort_values(ascending=False).head(10))
# Out:
# Top words in Arabic:
# في      2711
# من      1913
# على      975
# إلى      673
# أن       519
# التي     381
# عن       372
# عام      366
# أو       332
# ما       306
# Name: Arabic, dtype: Sparse[int64, 0]
# Top words in Chinese:
# 年月日       165
# 月日        146
# 年月         81
# mai        32
# live       30
# 賽德克        27
# kuraki     26
# tour       18
# best       16
# music      16
# Name: Chinese, dtype: Sparse[int64, 0]
# Top words in Dutch:
# van     2047
# het     1654
# een     1379
# en      1351
# op       624
# voor     575
# met      518
# door     500
# werd     489
# zijn     466
# Name: Dutch, dtype: Sparse[int64, 0]
# Top words in English:
# new       204
# school    178
# state     114
# time      111
# page      110
# film      101
# team      101
# years      89
# high       88
# world      88
# Name: English, dtype: Sparse[int64, 0]
# Top words in Estonian:
# ja        1320
# ta         371
# oli        324
# ning       269
# aastal     262
# ka         258
# mis        225
# kui        218
# või        182
# et         166
# Name: Estonian, dtype: Sparse[int64, 0]
# Top words in French:
# la      2216
# le      1912
# et      1557
# en      1459
# les     1115
# des      985
# du       942
# est      761
# dans     574
# une      556
# Name: French, dtype: Sparse[int64, 0]
# Top words in Hindi:
# और    1649
# पर    1273
# एक    1027
# रत     758
# कर     692
# इस     655
# यह     615
# वर     544
# अन     540
# रक     524
# Name: Hindi, dtype: Sparse[int64, 0]
# Top words in Indonesian:
# dan       1631
# yang      1615
# di        1144
# pada       828
# dari       734
# dengan     651
# ini        632
# untuk      479
# dalam      468
# adalah     440
# Name: Indonesian, dtype: Sparse[int64, 0]
# Top words in Japanese:
# また       136
# 昭和年       93
# 平成年       69
# しかし       49
# なお        45
# 年月日       35
# その後       32
# 月日        24
# en        16
# phase     13
# Name: Japanese, dtype: Sparse[int64, 0]
# Top words in Korean:
# 있다     380
# 그는     289
# 그의     248
# 있는     160
# 이후     155
# 그리고    139
# 또한     134
# 함께     132
# 한다     130
# 된다     123
# Name: Korean, dtype: Sparse[int64, 0]
# Top words in Latin:
# et      1251
# est      904
# anno     432
# ad       334
# die      329
# fuit     200
# cum      200
# sunt     192
# ab       159
# quae     153
# Name: Latin, dtype: Sparse[int64, 0]
# Top words in Persian:
# در     3550
# به     2501
# از     2220
# که     1547
# است    1536
# می     1524
# این    1248
# های    1024
# را      987
# با      828
# Name: Persian, dtype: Sparse[int64, 0]
# Top words in Portugese:
# em      1258
# da      1024
# que      999
# um       643
# uma      605
# os       573
# com      568
# se       528
# na       518
# para     505
# Name: Portugese, dtype: Sparse[int64, 0]
# Top words in Pushto:
# په     4798
# او     3085
# کې     1807
# چې     1585
# له     1104
# ته      899
# څخه     634
# دي      623
# سره     614
# هم      607
# Name: Pushto, dtype: Sparse[int64, 0]
# Top words in Romanian:
# în      1804
# și      1408
# din      959
# la       884
# cu       655
# este     544
# care     529
# pe       507
# fost     495
# mai      411
# Name: Romanian, dtype: Sparse[int64, 0]
# Top words in Russian:
# на      842
# по      420
# года    402
# не      294
# из      245
# что     229
# для     226
# его     215
# как     215
# году    201
# Name: Russian, dtype: Sparse[int64, 0]
# Top words in Spanish:
# la     2678
# en     2315
# el     2154
# que    1105
# los    1037
# del     973
# se      764
# por     735
# una     666
# su      623
# Name: Spanish, dtype: Sparse[int64, 0]
# Top words in Swedish:
# är         2486
# och        1486
# den        1468
# med         902
# av          897
# en          732
# som         654
# trakten     431
# om          392
# på          390
# Name: Swedish, dtype: Sparse[int64, 0]
# Top words in Tamil:
# கள    3637
# பட    1813
# என     831
# றத     628
# இந     593
# கப     588
# இர     581
# வர     521
# தல     520
# உள     493
# Name: Tamil, dtype: Sparse[int64, 0]
# Top words in Thai:
# เป     817
# นท     564
# ได     459
# พศ     408
# แต     273
# อย     237
# เร     227
# เม     210
# งเป    193
# มพ     192
# Name: Thai, dtype: Sparse[int64, 0]
# Top words in Turkish:
# ve            1683
# bir            941
# bu             440
# olarak         379
# ile            354
# olan           323
# da             312
# için           300
# tarafından     202
# yılında        201
# Name: Turkish, dtype: Sparse[int64, 0]
# Top words in Urdu:
# کے     2353
# میں    2168
# ہے     1926
# کی     1857
# اور    1766
# سے     1399
# کا     1200
# اس     1003
# کو      763
# ایک     699
# Name: Urdu, dtype: Sparse[int64, 0]

# %%
# Pairwise Language Similarity
# Analyze the similarity between different languages based on text data

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

# # Create TF-IDF matrix
# tfidf_vectorizer = TfidfVectorizer(stop_words='english')
# tfidf_matrix = tfidf_vectorizer.fit_transform(data['Text'])

# # Reduce dimensionality using TruncatedSVD
# svd = TruncatedSVD(n_components=100)
# tfidf_matrix_reduced = svd.fit_transform(tfidf_matrix)

# # Calculate cosine similarity
# similarities = cosine_similarity(tfidf_matrix_reduced, tfidf_matrix_reduced)

# # Create similarity DataFrame
# similarity_df = pd.DataFrame(similarities, index=data['language'], columns=data['language'])

# # Plot pairwise language similarity
# plt.figure(figsize=(12, 6))
# sns.heatmap(similarity_df, cmap='coolwarm')
# plt.title('Pairwise Language Similarity (TruncatedSVD)')
# plt.show()

# from sklearn.feature_extraction.text import TfidfVectorizer
# from datasketch import MinHash, MinHashLSH

# # Create TF-IDF vectorizer with stop words removed
# tfidf_vectorizer = TfidfVectorizer(stop_words='english')
# tfidf_matrix = tfidf_vectorizer.fit_transform(data['Text'])

# # Initialize MinHashLSH
# num_perm = 128  # Number of permutations
# lsh = MinHashLSH(threshold=0.5, num_perm=num_perm)

# # Create MinHash signatures and index
# for i, text in enumerate(data['Text']):
#     min_hash = MinHash(num_perm=num_perm)
#     for word in text.split():
#         min_hash.update(word.encode('utf-8'))
#     lsh.insert(i, min_hash)

# # Compute similar documents
# similar_docs = {}
# for i, text in enumerate(data['Text']):
#     min_hash_query = MinHash(num_perm=num_perm)
#     for word in text.split():
#         min_hash_query.update(word.encode('utf-8'))
#     results = lsh.query(min_hash_query)
#     similar_docs[i] = results

# # Print similar documents
# for i, results in similar_docs.items():
#     print(f"Similar documents to document {i}: {results}")


# from sklearn.feature_extraction.text import TfidfVectorizer
# from datasketch import MinHash, MinHashLSH

# # Create TF-IDF vectorizer with stop words removed
# tfidf_vectorizer = TfidfVectorizer(stop_words='english')
# tfidf_matrix = tfidf_vectorizer.fit_transform(data['Text'])

# # Initialize MinHashLSH
# num_perm = 128  # Number of permutations
# lsh = MinHashLSH(threshold=0.5, num_perm=num_perm)

# # Create MinHash signatures and index
# for i, text in enumerate(data['Text']):
#     min_hash = MinHash(num_perm=num_perm)
#     for word in text.split():
#         min_hash.update(word.encode('utf-8'))
#     lsh.insert(i, min_hash)

# # Compute similar documents
# similar_docs = {}
# for i, text in enumerate(data['Text']):
#     min_hash_query = MinHash(num_perm=num_perm)
#     for word in text.split():
#         min_hash_query.update(word.encode('utf-8'))
#     results = lsh.query(min_hash_query)
#     similar_docs[i] = results

# # Print similar documents with language names
# for i, results in similar_docs.items():
#     doc_language = data.loc[i, 'language']
#     print(f"Similar documents to document {i} ({doc_language}):")
#     for similar_doc_index in results:
#         similar_doc_language = data.loc[similar_doc_index, 'language']
#         print(f"  - Document {similar_doc_index}: {similar_doc_language}")



from sklearn.feature_extraction.text import TfidfVectorizer
from datasketch import MinHash, MinHashLSH

# Create TF-IDF vectorizer with stop words removed
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['Text'])

# Initialize MinHashLSH
num_perm = 128  # Number of permutations
lsh = MinHashLSH(threshold=0.5, num_perm=num_perm)

# Create MinHash signatures and index
for i, text in enumerate(data['Text']):
    min_hash = MinHash(num_perm=num_perm)
    for word in text.split():
        min_hash.update(word.encode('utf-8'))
    lsh.insert(i, min_hash)

# Compute similar documents
similar_docs = {}
for i, text in enumerate(data['Text']):
    min_hash_query = MinHash(num_perm=num_perm)
    for word in text.split():
        min_hash_query.update(word.encode('utf-8'))
    results = lsh.query(min_hash_query)
    similar_docs[i] = results

# Aggregate similar languages
similar_languages = {}
for i, results in similar_docs.items():
    doc_language = data.loc[i, 'language']
    if doc_language not in similar_languages:
        similar_languages[doc_language] = set()
    for similar_doc_index in results:
        similar_doc_language = data.loc[similar_doc_index, 'language']
        if similar_doc_language != doc_language:
            similar_languages[doc_language].add(similar_doc_language)

# Print similar languages
for language, similar_langs in similar_languages.items():
    print(f"Languages similar to {language}:")
    for similar_lang in similar_langs:
        print(f"  - {similar_lang}")
# Out:
# Similar documents to document 0 (Estonian):
#   - Document 0: Estonian
# Similar documents to document 1 (Swedish):
#   - Document 1: Swedish
# Similar documents to document 2 (Thai):
#   - Document 2: Thai
# Similar documents to document 3 (Tamil):
#   - Document 3: Tamil
# Similar documents to document 4 (Dutch):
#   - Document 10241: Dutch
#   - Document 18435: Dutch
#   - Document 4: Dutch
#   - Document 1673: Dutch
#   - Document 14987: Dutch
#   - Document 11532: Dutch
#   - Document 13457: Dutch
#   - Document 18449: Dutch
#   - Document 3863: Dutch
#   - Document 7323: Dutch
#   - Document 16542: Dutch
#   - Document 8223: Dutch
#   - Document 7712: Dutch
#   - Document 16929: Dutch
#   - Document 11811: Dutch
#   - Document 17834: Dutch
#   - Document 16044: Dutch
#   - Document 5932: Dutch
#   - Document 10414: Dutch
#   - Document 5933: Dutch
#   - Document 5168: Dutch
#   - Document 19128: Dutch
#   - Document 2489: Dutch
#   - Document 1593: Dutch
#   - Document 5436: Dutch
#   - Document 15811: Dutch
#   - Document 7620: Dutch
#   - Document 14792: Dutch
#   - Document 5322: Dutch
#   - Document 7242: Dutch
#   - Document 15180: Dutch
#   - Document 14927: Dutch
#   - Document 725: Dutch
#   - Document 17366: Dutch
#   - Document 10456: Dutch
#   - Document 2008: Dutch
#   - Document 13149: Dutch
#   - Document 3936: Dutch
#   - Document 12000: Dutch
#   - Document 17890: Dutch
#   - Document 5989: Dutch
#   - Document 7783: Dutch
#   - Document 10859: Dutch
#   - Document 14827: Dutch
#   - Document 5358: Dutch
#   - Document 21489: Dutch
#   - Document 6261: Dutch
#   - Document 21624: Dutch
#   - Document 12538: Dutch
#   - Document 16763: Dutch
#   - Document 6909: Dutch
#   - Document 638: Dutch
#   - Document 11903: Dutch
# Similar documents to document 5 (Japanese):
#   - Document 5: Japanese
# Similar documents to document 6 (Turkish):
#   - Document 6: Turkish
# Similar documents to document 7 (Latin):
#   - Document 7: Latin
# Similar documents to document 8 (Urdu):
#   - Document 8: Urdu
# Similar documents to document 9 (Japanese):
#   - Document 9: Japanese
# Similar documents to document 10 (Indonesian):
#   - Document 10: Indonesian
# Similar documents to document 11 (Portugese):
#   - Document 11: Portugese
# Similar documents to document 12 (French):
#   - Document 12: French
# Similar documents to document 13 (Chinese):
#   - Document 13: Chinese
# Similar documents to document 14 (Korean):
#   - Document 14: Korean
# Similar documents to document 15 (Thai):
#   - Document 15: Thai
# Similar documents to document 16 (Estonian):
#   - Document 16: Estonian
# Similar documents to document 17 (Portugese):
#   - Document 17: Portugese
# Similar documents to document 18 (Portugese):
#   - Document 18: Portugese
#   - Document 17758: Portugese
# Similar documents to document 19 (Hindi):
#   - Document 19: Hindi
# Similar documents to document 20 (Tamil):
#   - Document 20: Tamil
# Similar documents to document 21 (Spanish):
#   - Document 21: Spanish
# Similar documents to document 22 (French):
#   - Document 22: French
# Similar documents to document 23 (French):
#   - Document 23: French
# Similar documents to document 24 (Estonian):
#   - Document 24: Estonian
# Similar documents to document 25 (Korean):
#   - Document 25: Korean
# Similar documents to document 26 (French):
#   - Document 26: French
# Similar documents to document 27 (Pushto):
#   - Document 27: Pushto
# Similar documents to document 28 (Dutch):
#   - Document 28: Dutch
# Similar documents to document 29 (Persian):
#   - Document 29: Persian
# Similar documents to document 30 (French):
#   - Document 30: French
# Similar documents to document 31 (Romanian):
#   - Document 31: Romanian
# Similar documents to document 32 (Russian):
#   - Document 32: Russian
# Similar documents to document 33 (Japanese):
#   - Document 33: Japanese
# Similar documents to document 34 (Indonesian):
#   - Document 34: Indonesian
# Similar documents to document 35 (Latin):
#   - Document 35: Latin
# Similar documents to document 36 (Latin):
#   - Document 36: Latin
# Similar documents to document 37 (English):
#   - Document 37: English
# Similar documents to document 38 (French):
#   - Document 38: French
# Similar documents to document 39 (Portugese):
#   - Document 39: Portugese
# Similar documents to document 40 (English):
#   - Document 40: English
# Similar documents to document 41 (Urdu):
#   - Document 41: Urdu
# Similar documents to document 42 (Latin):
#   - Document 42: Latin
# Similar documents to document 43 (Indonesian):
#   - Document 43: Indonesian
# Similar documents to document 44 (Indonesian):
#   - Document 44: Indonesian
# Similar documents to document 45 (Japanese):
#   - Document 45: Japanese
# Similar documents to document 46 (Arabic):
#   - Document 46: Arabic
# Similar documents to document 47 (Pushto):
#   - Document 47: Pushto
# Similar documents to document 48 (Indonesian):
#   - Document 48: Indonesian
# Similar documents to document 49 (Swedish):
#   - Document 49: Swedish
# Similar documents to document 50 (Dutch):
#   - Document 50: Dutch
# Similar documents to document 51 (Russian):
#   - Document 51: Russian
# Similar documents to document 52 (Dutch):
#   - Document 52: Dutch
# Similar documents to document 53 (Arabic):
#   - Document 53: Arabic
# Similar documents to document 54 (Arabic):
#   - Document 54: Arabic
# Similar documents to document 55 (Turkish):
#   - Document 55: Turkish
# Similar documents to document 56 (Urdu):
#   - Document 56: Urdu
# Similar documents to document 57 (French):
#   - Document 57: French
# Similar documents to document 58 (Portugese):
#   - Document 58: Portugese
# Similar documents to document 59 (Portugese):
#   - Document 59: Portugese
# Similar documents to document 60 (Indonesian):
#   - Document 60: Indonesian
# Similar documents to document 61 (Indonesian):
#   - Document 61: Indonesian
# Similar documents to document 62 (Tamil):
#   - Document 62: Tamil
# Similar documents to document 63 (Swedish):
#   - Document 63: Swedish
# Similar documents to document 64 (Persian):
#   - Document 64: Persian
# Similar documents to document 65 (Russian):
#   - Document 65: Russian
# Similar documents to document 66 (Thai):
#   - Document 66: Thai
# Similar documents to document 67 (Korean):
#   - Document 67: Korean
# Similar documents to document 68 (Urdu):
#   - Document 68: Urdu
# Similar documents to document 69 (Thai):
#   - Document 69: Thai
# Similar documents to document 70 (Portugese):
#   - Document 70: Portugese
# Similar documents to document 71 (Arabic):
#   - Document 71: Arabic
# Similar documents to document 72 (Tamil):
#   - Document 72: Tamil
# Similar documents to document 73 (Pushto):
#   - Document 73: Pushto
# Similar documents to document 74 (Urdu):
#   - Document 74: Urdu
# Similar documents to document 75 (Pushto):
#   - Document 75: Pushto
# Similar documents to document 76 (English):
#   - Document 76: English
# Similar documents to document 77 (Russian):
#   - Document 77: Russian
# Similar documents to document 78 (Persian):
#   - Document 78: Persian
# Similar documents to document 79 (Japanese):
#   - Document 79: Japanese
# Similar documents to document 80 (Portugese):
#   - Document 80: Portugese
# Similar documents to document 81 (Hindi):
#   - Document 81: Hindi
# Similar documents to document 82 (Persian):
#   - Document 353: Persian
#   - Document 11458: Persian
#   - Document 16099: Persian
#   - Document 5132: Persian
#   - Document 13165: Persian
#   - Document 82: Persian
# Similar documents to document 83 (Korean):
#   - Document 83: Korean
# Similar documents to document 84 (Swedish):
#   - Document 84: Swedish
# Similar documents to document 85 (Indonesian):
#   - Document 85: Indonesian
# Similar documents to document 86 (Latin):
#   - Document 86: Latin
# Similar documents to document 87 (French):
#   - Document 87: French
# Similar documents to document 88 (Latin):
#   - Document 1152: Latin
#   - Document 12612: Latin
#   - Document 17674: Latin
#   - Document 20458: Latin
#   - Document 4299: Latin
#   - Document 11698: Latin
#   - Document 88: Latin
#   - Document 6366: Latin
#   - Document 5374: Latin
# Similar documents to document 89 (Pushto):
#   - Document 89: Pushto
# Similar documents to document 90 (English):
#   - Document 90: English
# Similar documents to document 91 (Estonian):
#   - Document 91: Estonian
# Similar documents to document 92 (Indonesian):
#   - Document 92: Indonesian
# Similar documents to document 93 (Tamil):
#   - Document 93: Tamil
# Similar documents to document 94 (Tamil):
#   - Document 94: Tamil
# Similar documents to document 95 (Latin):
#   - Document 95: Latin
# Similar documents to document 96 (Latin):
#   - Document 96: Latin
# Similar documents to document 97 (English):
#   - Document 97: English
# Similar documents to document 98 (Pushto):
#   - Document 98: Pushto
# Similar documents to document 99 (Korean):
#   - Document 99: Korean
# Similar documents to document 100 (Japanese):
#   - Document 100: Japanese
# Similar documents to document 101 (Russian):
#   - Document 101: Russian
# Similar documents to document 102 (Tamil):
#   - Document 102: Tamil
# Similar documents to document 103 (Persian):
#   - Document 103: Persian
# Similar documents to document 104 (Thai):
#   - Document 104: Thai
# Similar documents to document 105 (Turkish):
#   - Document 105: Turkish
# Similar documents to document 106 (Estonian):
#   - Document 106: Estonian
# Similar documents to document 107 (English):
#   - Document 107: English
# Similar documents to document 108 (Swedish):
#   - Document 108: Swedish
# Similar documents to document 109 (Japanese):
#   - Document 109: Japanese
# Similar documents to document 110 (Chinese):
#   - Document 110: Chinese
# Similar documents to document 111 (Thai):
#   - Document 111: Thai
# Similar documents to document 112 (French):
#   - Document 112: French
# Similar documents to document 113 (Arabic):
#   - Document 113: Arabic
# Similar documents to document 114 (Romanian):
#   - Document 114: Romanian
#   - Document 8542: Swedish
#   - Document 17253: Swedish
#   - Document 9578: Swedish
#   - Document 10093: Swedish
#   - Document 20846: Swedish
#   - Document 21360: Swedish
#   - Document 6019: Swedish
#   - Document 15242: Swedish
#   - Document 18827: Swedish
#   - Document 12175: Swedish
#   - Document 14736: Swedish
#   - Document 10640: Swedish
#   - Document 11167: Swedish
#   - Document 11181: Swedish
#   - Document 20909: Swedish
#   - Document 9648: Swedish
#   - Document 9139: Swedish
#   - Document 20408: Swedish
#   - Document 9149: Swedish
#   - Document 7107: Swedish
#   - Document 454: Swedish
#   - Document 21455: Swedish
#   - Document 16335: Swedish
#   - Document 13782: Swedish
#   - Document 12759: Swedish
#   - Document 2012: Swedish
#   - Document 21470: Swedish
#   - Document 13794: Swedish
#   - Document 10219: Swedish
#   - Document 1517: Swedish
#   - Document 20462: Swedish
#   - Document 10737: Swedish
#   - Document 13817: Swedish
# Similar documents to document 136 (Urdu):
#   - Document 136: Urdu
# Similar documents to document 137 (Russian):
#   - Document 137: Russian
# Similar documents to document 138 (Latin):
#   - Document 517: Latin
#   - Document 138: Latin
#   - Document 9834: Latin
#   - Document 11083: Latin
#   - Document 749: Latin
#   - Document 18798: Latin
#   - Document 3024: Latin
#   - Document 2516: Latin
#   - Document 2614: Latin
#   - Document 6812: Latin
#   - Document 11327: Latin
# Similar documents to document 139 (Latin):
#   - Document 139: Latin
# Similar documents to document 140 (Korean):
#   - Document 140: Korean
# Similar documents to document 141 (Tamil):
#   - Document 141: Tamil
# Similar documents to document 142 (Turkish):
#   - Document 142: Turkish
#   - Document 14869: Turkish
#   - Document 2839: Turkish
#   - Document 15128: Turkish
#   - Document 16677: Turkish
#   - Document 11694: Turkish
#   - Document 5426: Turkish
#   - Document 18867: Turkish
#   - Document 10170: Turkish
#   - Document 12873: Turkish
#   - Document 21577: Turkish
#   - Document 5978: Turkish
#   - Document 19039: Turkish
#   - Document 4324: Turkish
#   - Document 16614: Turkish
#   - Document 15719: Turkish
#   - Document 7146: Turkish
#   - Document 1515: Turkish
#   - Document 1390: Turkish
#   - Document 1654: Turkish
#   - Document 9722: Turkish
# Similar documents to document 143 (Swedish):
#   - Document 143: Swedish
# Similar documents to document 144 (Hindi):
#   - Document 144: Hindi
# Similar documents to document 145 (Hindi):
#   - Document 145: Hindi
# Similar documents to document 146 (Turkish):
#   - Document 146: Turkish
# Similar documents to document 147 (Hindi):
#   - Document 147: Hindi
# Similar documents to document 148 (Thai):
#   - Document 148: Thai
# Similar documents to document 149 (Hindi):
#   - Document 149: Hindi
# Similar documents to document 150 (Turkish):
#   - Document 150: Turkish
# Similar documents to document 151 (Chinese):
#   - Document 151: Chinese
# Similar documents to document 152 (Portugese):
#   - Document 152: Portugese
#   - Document 9508: Portugese
# Similar documents to document 153 (Turkish):
#   - Document 153: Turkish
# Similar documents to document 154 (Urdu):
#   - Document 154: Urdu
# Similar documents to document 155 (English):
#   - Document 155: English
# Similar documents to document 156 (English):
#   - Document 156: English
# Similar documents to document 157 (French):
#   - Document 157: French
# Similar documents to document 158 (English):
#   - Document 158: English
# Similar documents to document 159 (Thai):
#   - Document 17208: Thai
#   - Document 11787: Thai
#   - Document 18695: Thai
#   - Document 159: Thai
# Similar documents to document 160 (Korean):
#   - Document 160: Korean
# Similar documents to document 161 (Japanese):
#   - Document 161: Japanese
# Similar documents to document 162 (Spanish):
#   - Document 162: Spanish
# Similar documents to document 163 (English):
#   - Document 163: English
# Similar documents to document 164 (Turkish):
#   - Document 164: Turkish
# Similar documents to document 165 (Portugese):
#   - Document 165: Portugese
# Similar documents to document 166 (Indonesian):
#   - Document 14272: Indonesian
#   - Document 1027: Indonesian
#   - Document 3429: Indonesian
#   - Document 166: Indonesian
#   - Document 13319: Indonesian
#   - Document 7366: Indonesian
#   - Document 10731: Indonesian
#   - Document 3788: Indonesian
#   - Document 17902: Indonesian
#   - Document 19856: Indonesian
#   - Document 17427: Indonesian
#   - Document 13816: Indonesian
#   - Document 2265: Indonesian
#   - Document 410: Indonesian
#   - Document 12063: Indonesian
# Similar documents to document 167 (English):
#   - Document 167: English
# Similar documents to document 168 (French):
#   - Document 168: French
# Similar documents to document 169 (Thai):
#   - Document 169: Thai
# Similar documents to document 170 (Japanese):
#   - Document 170: Japanese
# Similar documents to document 171 (Tamil):
#   - Document 20320: Tamil
#   - Document 4992: Tamil
#   - Document 8609: Tamil
#   - Document 20832: Tamil
#   - Document 15178: Tamil
#   - Document 171: Tamil
#   - Document 2507: Tamil
#   - Document 15759: Tamil
#   - Document 18397: Tamil
#   - Document 20372: Tamil
#   - Document 9782: Tamil
#   - Document 21142: Tamil
#   - Document 13434: Tamil
#   - Document 12893: Tamil
# Similar documents to document 172 (Korean):
#   - Document 172: Korean
# Similar documents to document 173 (Dutch):
#   - Document 173: Dutch
# Similar documents to document 174 (Swedish):
#   - Document 174: Swedish
# Similar documents to document 175 (Persian):
#   - Document 175: Persian
# Similar documents to document 176 (Indonesian):
#   - Document 176: Indonesian
# Similar documents to document 177 (Dutch):
#   - Document 177: Dutch
# Similar documents to document 178 (Estonian):
#   - Document 178: Estonian
# Similar documents to document 179 (Turkish):
#   - Document 179: Turkish
# Similar documents to document 180 (Portugese):
#   - Document 180: Portugese
# Similar documents to document 181 (Estonian):
#   - Document 181: Estonian
# Similar documents to document 182 (Arabic):
#   - Document 182: Arabic
# Similar documents to document 183 (Turkish):
#   - Document 183: Turkish
# Similar documents to document 184 (French):
#   - Document 184: French
# Similar documents to document 185 (Pushto):
#   - Document 185: Pushto
# Similar documents to document 186 (Urdu):
#   - Document 2820: Urdu
#   - Document 20102: Urdu
#   - Document 18438: Urdu
#   - Document 12294: Urdu
#   - Document 12671: Urdu
#   - Document 6796: Urdu
#   - Document 4750: Urdu
#   - Document 3215: Urdu
#   - Document 14608: Urdu
#   - Document 792: Urdu
#   - Document 10907: Urdu
#   - Document 8862: Urdu
#   - Document 16031: Urdu
#   - Document 10361: Urdu
#   - Document 11938: Urdu
#   - Document 10660: Urdu
#   - Document 5028: Urdu
#   - Document 3111: Urdu
#   - Document 21419: Urdu
#   - Document 1964: Urdu
#   - Document 2732: Urdu
#   - Document 303: Urdu
#   - Document 11568: Urdu
#   - Document 10548: Urdu
#   - Document 21686: Urdu
#   - Document 21175: Urdu
#   - Document 186: Urdu
#   - Document 19387: Urdu
#   - Document 21693: Urdu
#   - Document 20799: Urdu
#   - Document 8640: Urdu
#   - Document 18758: Urdu
#   - Document 5958: Urdu
#   - Document 3529: Urdu
#   - Document 16843: Urdu
#   - Document 591: Urdu
#   - Document 8912: Urdu
#   - Document 14804: Urdu
#   - Document 16602: Urdu
#   - Document 6492: Urdu
#   - Document 3166: Urdu
#   - Document 19551: Urdu
#   - Document 17118: Urdu
#   - Document 7138: Urdu
#   - Document 4195: Urdu
#   - Document 3811: Urdu
#   - Document 14056: Urdu
#   - Document 11753: Urdu
#   - Document 15984: Urdu
#   - Document 5618: Urdu
#   - Document 2163: Urdu
#   - Document 11890: Urdu
#   - Document 21746: Urdu
#   - Document 2168: Urdu
#   - Document 249: Urdu
#   - Document 1531: Urdu
#   - Document 14332: Urdu
#   - Document 6015: Urdu
# Similar documents to document 187 (Thai):
#   - Document 187: Thai
# Similar documents to document 188 (Romanian):
#   - Document 188: Romanian
# Similar documents to document 189 (Russian):
#   - Document 189: Russian
# Similar documents to document 190 (French):
#   - Document 190: French
# Similar documents to document 191 (Spanish):
#   - Document 191: Spanish
# Similar documents to document 192 (Portugese):
#   - Document 192: Portugese
#   - Document 19065: Portugese
#   - Document 12926: Portugese
# Similar documents to document 193 (Persian):
#   - Document 193: Persian
# Similar documents to document 194 (Persian):
#   - Document 194: Persian
# Similar documents to document 195 (Spanish):
#   - Document 195: Spanish
# Similar documents to document 196 (Romanian):
#   - Document 196: Romanian
# Similar documents to document 197 (Japanese):
#   - Document 197: Japanese
# Similar documents to document 198 (Thai):
#   - Document 198: Thai
# Similar documents to document 199 (Turkish):
#   - Document 199: Turkish
#   - Document 5671: Turkish
#   - Document 14286: Turkish
#   - Document 21877: Turkish
#   - Document 7671: Turkish
#   - Document 16248: Turkish
#   - Document 7803: Turkish
# Similar documents to document 200 (Turkish):
#   - Document 200: Turkish
# Similar documents to document 201 (Russian):
#   - Document 201: Russian
# Similar documents to document 202 (Swedish):
#   - Document 202: Swedish
# Similar documents to document 203 (Swedish):
#   - Document 203: Swedish
# Similar documents to document 204 (Portugese):
#   - Document 204: Portugese
# Similar documents to document 205 (Dutch):
#   - Document 205: Dutch
# Similar documents to document 206 (Indonesian):
#   - Document 206: Indonesian
# Similar documents to document 207 (Hindi):
#   - Document 207: Hindi
# Similar documents to document 208 (Dutch):
#   - Document 208: Dutch
# Similar documents to document 209 (Swedish):
#   - Document 8701: Swedish
#   - Document 16514: Swedish
#   - Document 4987: Swedish
#   - Document 6276: Swedish
#   - Document 14725: Swedish
#   - Document 19718: Swedish
#   - Document 1033: Swedish
#   - Document 3210: Swedish
#   - Document 6155: Swedish
#   - Document 16397: Swedish
#   - Document 11409: Swedish
#   - Document 15542: Latin
#   - Document 6078: Latin
#   - Document 9920: Latin
#   - Document 11460: Latin
#   - Document 12613: Latin
#   - Document 15303: Latin
#   - Document 5576: Latin
#   - Document 12105: Latin
#   - Document 8650: Latin
#   - Document 6603: Latin
#   - Document 20427: Latin
#   - Document 1231: Latin
#   - Document 2000: Latin
#   - Document 7632: Latin
#   - Document 13909: Latin
#   - Document 16342: Latin
#   - Document 11867: Latin
#   - Document 222: Latin
#   - Document 9823: Latin
#   - Document 9830: Latin
#   - Document 16489: Latin
#   - Document 18026: Latin
#   - Document 4974: Latin
#   - Document 19572: Latin
#   - Document 19061: Latin
#   - Document 11899: Latin
# Similar documents to document 223 (Dutch):
#   - Document 223: Dutch
# Similar documents to document 224 (Hindi):
#   - Document 224: Hindi
# Similar documents to document 225 (Russian):
#   - Document 225: Russian
# Similar documents to document 226 (Russian):
#   - Document 226: Russian
# Similar documents to document 227 (Chinese):
#   - Document 227: Chinese
# Similar documents to document 228 (Romanian):
#   - Document 228: Romanian
# Similar documents to document 229 (Arabic):
#   - Document 229: Arabic
# Similar documents to document 230 (English):
#   - Document 230: English
# Similar documents to document 231 (Latin):
#   - Document 231: Latin
# Similar documents to document 232 (Indonesian):
#   - Document 232: Indonesian
# Similar documents to document 233 (Russian):
#   - Document 233: Russian
# Similar documents to document 234 (Latin):
#   - Document 234: Latin
# Similar documents to document 235 (English):
#   - Document 235: English
# Similar documents to document 236 (Swedish):
#   - Document 236: Swedish
# Similar documents to document 237 (English):
#   - Document 237: English
# Similar documents to document 238 (Pushto):
#   - Document 1691: Pushto
#   - Document 238: Pushto
# Similar documents to document 239 (Tamil):
#   - Document 239: Tamil
# Similar documents to document 240 (Hindi):
#   - Document 240: Hindi
# Similar documents to document 241 (Estonian):
#   - Document 241: Estonian
# Similar documents to document 242 (Latin):
#   - Document 242: Latin
# Similar documents to document 243 (Russian):
#   - Document 243: Russian
# Similar documents to document 244 (Indonesian):
#   - Document 244: Indonesian
# Similar documents to document 245 (Urdu):
#   - Document 245: Urdu
# Similar documents to document 246 (Japanese):
#   - Document 246: Japanese
# Similar documents to document 247 (Hindi):
#   - Document 247: Hindi
# Similar documents to document 248 (Pushto):
#   - Document 248: Pushto
# Similar documents to document 249 (Urdu):
#   - Document 2820: Urdu
#   - Document 20102: Urdu
#   - Document 18438: Urdu
#   - Document 12294: Urdu
#   - Document 12671: Urdu
#   - Document 6796: Urdu
#   - Document 4750: Urdu
#   - Document 3215: Urdu
#   - Document 14608: Urdu
#   - Document 792: Urdu
#   - Document 10907: Urdu
#   - Document 8862: Urdu
#   - Document 16031: Urdu
#   - Document 10361: Urdu
#   - Document 10660: Urdu
#   - Document 5028: Urdu
#   - Document 3111: Urdu
#   - Document 21419: Urdu
#   - Document 1964: Urdu
#   - Document 2732: Urdu
#   - Document 303: Urdu
#   - Document 11568: Urdu
#   - Document 10548: Urdu
#   - Document 21686: Urdu
#   - Document 21175: Urdu
#   - Document 186: Urdu
#   - Document 19387: Urdu
#   - Document 21693: Urdu
#   - Document 20799: Urdu
#   - Document 8640: Urdu
#   - Document 5958: Urdu
#   - Document 18758: Urdu
#   - Document 3529: Urdu
#   - Document 16843: Urdu
#   - Document 591: Urdu
#   - Document 14804: Urdu
#   - Document 16602: Urdu
#   - Document 6492: Urdu
#   - Document 3166: Urdu
#   - Document 19551: Urdu
#   - Document 17118: Urdu
#   - Document 7138: Urdu
#   - Document 4195: Urdu
#   - Document 3811: Urdu
#   - Document 14056: Urdu
#   - Document 11753: Urdu
#   - Document 15984: Urdu
#   - Document 5618: Urdu
#   - Document 11890: Urdu
#   - Document 21746: Urdu
#   - Document 2163: Urdu
#   - Document 2168: Urdu
#   - Document 249: Urdu
#   - Document 1531: Urdu
#   - Document 14332: Urdu
#   - Document 6015: Urdu
# Similar documents to document 250 (Chinese):
#   - Document 250: Chinese
# Similar documents to document 251 (Swedish):
#   - Document 251: Swedish
# Similar documents to document 252 (Dutch):
#   - Document 252: Dutch
# Similar documents to document 253 (Latin):
#   - Document 253: Latin
# Similar documents to document 254 (Persian):
#   - Document 254: Persian
# Similar documents to document 255 (Turkish):
#   - Document 255: Turkish
# Similar documents to document 256 (Japanese):
#   - Document 256: Japanese
# Similar documents to document 257 (Pushto):
#   - Document 257: Pushto
#   - Document 3505: Pushto
#   - Document 2613: Pushto
# Similar documents to document 258 (Pushto):
#   - Document 258: Pushto
# Similar documents to document 259 (Indonesian):
#   - Document 259: Indonesian
# Similar documents to document 260 (Korean):
#   - Document 260: Korean
# Similar documents to document 261 (Portugese):
#   - Document 261: Portugese
# Similar documents to document 262 (Spanish):
#   - Document 21626: Spanish
#   - Document 262: Spanish
# Similar documents to document 263 (Urdu):
#   - Document 263: Urdu
# Similar documents to document 264 (English):
#   - Document 264: English
# Similar documents to document 265 (Russian):
#   - Document 265: Russian
# Similar documents to document 266 (Thai):
#   - Document 266: Thai
# Similar documents to document 267 (Chinese):
#   - Document 267: Chinese
# Similar documents to document 268 (Persian):
#   - Document 268: Persian
# Similar documents to document 269 (Turkish):
#   - Document 269: Turkish
# Similar documents to document 270 (Arabic):
#   - Document 270: Arabic
# Similar documents to document 271 (Urdu):
#   - Document 271: Urdu
# Similar documents to document 272 (Latin):
#   - Document 272: Latin
# Similar documents to document 273 (Estonian):
#   - Document 273: Estonian
# Similar documents to document 274 (Urdu):
#   - Document 9449: Urdu
#   - Document 274: Urdu
#   - Document 7054: Urdu
# Similar documents to document 275 (Pushto):
#   - Document 275: Pushto
# Similar documents to document 276 (Chinese):
#   - Document 276: Chinese
# Similar documents to document 277 (Latin):
#   - Document 277: Latin
# Similar documents to document 278 (Thai):
#   - Document 278: Thai
# Similar documents to document 279 (Thai):
#   - Document 279: Thai
# Similar documents to document 280 (English):
#   - Document 280: English
# Similar documents to document 281 (Romanian):
#   - Document 281: Romanian
# Similar documents to document 282 (Estonian):
#   - Document 282: Estonian
# Similar documents to document 283 (Turkish):
#   - Document 283: Turkish
# Similar documents to document 284 (Swedish):
#   - Document 6657: Swedish
#   - Document 4552: Swedish
#   - Document 16335: Swedish
#   - Document 19408: Swedish
#   - Document 13782: Swedish
#   - Document 12759: Swedish
#   - Document 2012: Swedish
#   - Document 21470: Swedish
#   - Document 10207: Swedish
#   - Document 13794: Swedish
#   - Document 10732: Swedish
#   - Document 1517: Swedish
#   - Document 20462: Swedish
#   - Document 7151: Swedish
#   - Document 12269: Swedish
#   - Document 10737: Swedish
#   - Document 13817: Swedish
# Similar documents to document 285 (Spanish):
#   - Document 285: Spanish
# Similar documents to document 286 (Russian):
#   - Document 286: Russian
# Similar documents to document 287 (Spanish):
#   - Document 287: Spanish
# Similar documents to document 288 (Russian):
#   - Document 288: Russian
# Similar documents to document 289 (Korean):
#   - Document 289: Korean
# Similar documents to document 290 (Arabic):
#   - Document 290: Arabic
# Similar documents to document 291 (Estonian):
#   - Document 291: Estonian
# Similar documents to document 292 (Turkish):
#   - Document 292: Turkish
# Similar documents to document 293 (Russian):
#   - Document 2498: Russian
#   - Document 12347: Russian
#   - Document 293: Russian
# Similar documents to document 294 (Urdu):
#   - Document 294: Urdu
# Similar documents to document 295 (Estonian):
#   - Document 295: Estonian
# Similar documents to document 296 (Estonian):
#   - Document 296: Estonian
# Similar documents to document 297 (Portugese):
#   - Document 297: Portugese
# Similar documents to document 298 (Estonian):
#   - Document 298: Estonian
# Similar documents to document 299 (Portugese):
#   - Document 299: Portugese
# Similar documents to document 300 (Japanese):
#   - Document 300: Japanese
# Similar documents to document 301 (Indonesian):
#   - Document 301: Indonesian
# Similar documents to document 302 (Portugese):
#   - Document 302: Portugese
# Similar documents to document 303 (Urdu):
#   - Document 2820: Urdu
#   - Document 18438: Urdu
#   - Document 12294: Urdu
#   - Document 20102: Urdu
#   - Document 6796: Urdu
#   - Document 4750: Urdu
#   - Document 3215: Urdu
#   - Document 14608: Urdu
#   - Document 792: Urdu
#   - Document 11672: Urdu
#   - Document 10907: Urdu
#   - Document 8862: Urdu
#   - Document 16031: Urdu
#   - Document 5028: Urdu
#   - Document 10660: Urdu
#   - Document 3111: Urdu
#   - Document 21419: Urdu
#   - Document 2732: Urdu
#   - Document 1964: Urdu
#   - Document 303: Urdu
#   - Document 11568: Urdu
#   - Document 10548: Urdu
#   - Document 21686: Urdu
#   - Document 6015: Urdu
#   - Document 21175: Urdu
#   - Document 186: Urdu
#   - Document 19387: Urdu
#   - Document 21693: Urdu
#   - Document 20799: Urdu
#   - Document 8640: Urdu
#   - Document 18758: Urdu
#   - Document 5958: Urdu
#   - Document 3529: Urdu
#   - Document 16843: Urdu
#   - Document 591: Urdu
#   - Document 14804: Urdu
#   - Document 16602: Urdu
#   - Document 6492: Urdu
#   - Document 4700: Urdu
#   - Document 3166: Urdu
#   - Document 19551: Urdu
#   - Document 17118: Urdu
#   - Document 7138: Urdu
#   - Document 4195: Urdu
#   - Document 3811: Urdu
#   - Document 249: Urdu
#   - Document 14056: Urdu
#   - Document 11753: Urdu
#   - Document 15984: Urdu
#   - Document 5618: Urdu
#   - Document 2163: Urdu
#   - Document 15572: Swedish
#   - Document 20693: Swedish
#   - Document 16601: Swedish
#   - Document 20700: Swedish
#   - Document 3810: Swedish
#   - Document 11495: Swedish
#   - Document 5357: Swedish
#   - Document 18157: Swedish
#   - Document 8430: Swedish
#   - Document 7407: Swedish
#   - Document 3824: Swedish
#   - Document 1273: Swedish
#   - Document 1282: Swedish
#   - Document 772: Swedish
#   - Document 2314: Swedish
#   - Document 13076: Swedish
# ...
#   - Document 16372: Estonian
# Similar documents to document 16373 (Urdu):
#   - Document 2688: Urdu
#   - Document 8962: Urdu
#   - Document 3330: Urdu
#   - Document 14213: Urdu
#   - Document 15115: Urdu
#   - Document 9230: Urdu
#   - Document 9742: Urdu
#   - Document 17169: Urdu
#   - Document 4378: Urdu
#   - Document 19114: Urdu
#   - Document 17581: Urdu
#   - Document 16558: Urdu
#   - Document 11956: Urdu
#   - Document 6198: Urdu
#   - Document 6977: Urdu
#   - Document 4034: Urdu
#   - Document 1603: Urdu
#   - Document 17612: Urdu
#   - Document 9804: Urdu
#   - Document 17103: Urdu
#   - Document 19281: Urdu
#   - Document 19796: Urdu
#   - Document 18272: Urdu
#   - Document 17123: Urdu
#   - Document 15593: Urdu
#   - Document 13930: Urdu
#   - Document 12783: Urdu
#   - Document 11376: Urdu
#   - Document 14964: Urdu
#   - Document 16373: Urdu
#   - Document 15094: Urdu
# Similar documents to document 16374 (Korean):
#   - Document 16374: Korean
# Similar documents to document 16375 (Thai):
#   - Document 16375: Thai
# Similar documents to document 16376 (Chinese):
#   - Document 16376: Chinese
# Similar documents to document 16377 (Pushto):
#   - Document 16377: Pushto
# Similar documents to document 16378 (Pushto):
#   - Document 16378: Pushto
# Similar documents to document 16379 (Persian):
#   - Document 16379: Persian
# Similar documents to document 16380 (Thai):
#   - Document 16380: Thai
# Similar documents to document 16381 (Tamil):
#   - Document 16381: Tamil
# Similar documents to document 16382 (Chinese):
#   - Document 16382: Chinese
# Similar documents to document 16383 (Indonesian):
#   - Document 16383: Indonesian
# Similar documents to document 16384 (Urdu):
#   - Document 16384: Urdu
# Similar documents to document 16385 (French):
#   - Document 16385: French
# Similar documents to document 16386 (Urdu):
#   - Document 16386: Urdu
# Similar documents to document 16387 (Turkish):
#   - Document 16387: Turkish
# Similar documents to document 16388 (Hindi):
#   - Document 15786: Hindi
#   - Document 21155: Hindi
#   - Document 16388: Hindi
#   - Document 13903: Hindi
# Similar documents to document 16389 (Turkish):
#   - Document 16389: Turkish
# Similar documents to document 16390 (Korean):
#   - Document 16390: Korean
# Similar documents to document 16391 (Turkish):
#   - Document 16391: Turkish
# Similar documents to document 16392 (Tamil):
#   - Document 16392: Tamil
# Similar documents to document 16393 (French):
#   - Document 3032: French
#   - Document 16393: French
# Similar documents to document 16394 (Latin):
#   - Document 16394: Latin
# Similar documents to document 16395 (Indonesian):
#   - Document 16395: Indonesian
# Similar documents to document 16396 (Hindi):
#   - Document 16396: Hindi
# Similar documents to document 16397 (Swedish):
#   - Document 15361: Swedish
#   - Document 8708: Swedish
#   - Document 16427: Chinese
# Similar documents to document 16428 (Turkish):
#   - Document 16428: Turkish
# Similar documents to document 16429 (Swedish):
#   - Document 16429: Swedish
# Similar documents to document 16430 (Estonian):
#   - Document 16430: Estonian
# Similar documents to document 16431 (English):
#   - Document 16431: English
# Similar documents to document 16432 (Chinese):
#   - Document 16432: Chinese
# Similar documents to document 16433 (Arabic):
#   - Document 16433: Arabic
# Similar documents to document 16434 (Chinese):
#   - Document 16434: Chinese
# Similar documents to document 16435 (Spanish):
#   - Document 16435: Spanish
# Similar documents to document 16436 (English):
#   - Document 16436: English
# Similar documents to document 16437 (Turkish):
#   - Document 16437: Turkish
# Similar documents to document 16438 (Urdu):
#   - Document 16438: Urdu
# Similar documents to document 16439 (Persian):
#   - Document 16439: Persian
# Similar documents to document 16440 (Persian):
#   - Document 16440: Persian
# Similar documents to document 16441 (Dutch):
#   - Document 16441: Dutch
# Similar documents to document 16442 (Indonesian):
#   - Document 16442: Indonesian
# Similar documents to document 16443 (Urdu):
#   - Document 16443: Urdu
# Similar documents to document 16444 (Romanian):
#   - Document 16444: Romanian
# Similar documents to document 16445 (French):
#   - Document 16445: French
# Similar documents to document 16446 (Estonian):
#   - Document 16446: Estonian
# Similar documents to document 16447 (Urdu):
#   - Document 16447: Urdu
# Similar documents to document 16448 (English):
#   - Document 16448: English
# Similar documents to document 16449 (English):
#   - Document 16449: English
# Similar documents to document 16450 (French):
#   - Document 16450: French
# Similar documents to document 16451 (Spanish):
#   - Document 16451: Spanish
# Similar documents to document 16452 (Estonian):
#   - Document 16452: Estonian
# Similar documents to document 16453 (English):
#   - Document 18280: English
#   - Document 16453: English
# Similar documents to document 16454 (Latin):
#   - Document 16454: Latin
# Similar documents to document 16455 (Indonesian):
#   - Document 16455: Indonesian
# Similar documents to document 16456 (Spanish):
#   - Document 16456: Spanish
# Similar documents to document 16457 (Turkish):
#   - Document 16457: Turkish
# Similar documents to document 16458 (English):
#   - Document 16458: English
# Similar documents to document 16459 (Swedish):
#   - Document 16459: Swedish
# Similar documents to document 16460 (Latin):
#   - Document 16460: Latin
# Similar documents to document 16461 (Urdu):
#   - Document 16461: Urdu
# Similar documents to document 16462 (Persian):
#   - Document 16462: Persian
# Similar documents to document 16463 (Persian):
#   - Document 16463: Persian
# Similar documents to document 16464 (Estonian):
#   - Document 16464: Estonian
# Similar documents to document 16465 (Pushto):
#   - Document 16465: Pushto
# Similar documents to document 16466 (Swedish):
#   - Document 7820: Swedish
#   - Document 7565: Swedish
#   - Document 15378: Swedish
#   - Document 8724: Swedish
#   - Document 5537: Swedish
#   - Document 7981: Swedish
#   - Document 5942: Swedish
#   - Document 12343: Swedish
#   - Document 15162: Swedish
#   - Document 21694: Swedish
#   - Document 1856: Swedish
#   - Document 7623: Swedish
#   - Document 17354: Swedish
#   - Document 6351: Swedish
#   - Document 10320: Swedish
#   - Document 21457: Swedish
#   - Document 16466: Swedish
#   - Document 9936: Swedish
#   - Document 10069: Swedish
#   - Document 5591: Swedish
